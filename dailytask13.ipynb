# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnu4510/datascience/blob/main/dailytask13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Take input of age of 3 people by user and determine oldest and
# youngest among them.**

# %%
age1 = int(input("Enter the age of the first person: "))
age2 = int(input("Enter the age of the second person: "))
age3 = int(input("Enter the age of the third person: "))

oldest = max(age1, age2, age3)
youngest = min(age1, age2, age3)

print(f"The oldest person is {oldest} years old.")
print(f"The youngest person is {youngest} years old.")
# Out:
# Enter the age of the first person: 35
# Enter the age of the second person: 47
# Enter the age of the third person: 22
# The oldest person is 47 years old.
# The youngest person is 22 years old.

# %% [markdown]
# **2. Write a program that asks the user for their exam score and
# calculates their grade based on the following conditions:
# a. A score of 90 or above is an A.
# b. A score between 80 and 89 is a B.
# c. A score between 70 and 79 is a C.
# d. A score below 70 is an F.**

# %%
score = int(input("Enter your exam score: "))

if score >= 90:
    grade = 'A'
elif 80 <= score < 90:
    grade = 'B'
elif 70 <= score < 80:
    grade = 'C'
else:
    grade = 'F'

print(f"Your grade is: {grade}")
# Out:
# Enter your exam score: 99
# Your grade is: A

# %% [markdown]
# **3. Create a program that asks the user for a list of grocery items they
# need to buy and organizes the list alphabetically**

# %%
grocery_items = input("Enter the grocery items you need to buy, separated by commas: ").split(',')

grocery_items = [item.strip() for item in grocery_items]
grocery_items.sort()

print("Your grocery list in alphabetical order:")
for item in grocery_items:
    print(item)
# Out:
# Enter the grocery items you need to buy, separated by commas: milk,egg,apple
# Your grocery list in alphabetical order:
# apple
# egg
# milk

# %% [markdown]
# **4. Write a program that asks the user for an email address and
# checks if it is valid (contains an "@" symbol and a valid domain).**

# %%
email = input("Enter your email address: ")

# Basic email validation
if "@" in email and "." in email.split("@")[-1]:
    print("The email address is valid.")
else:
    print("The email address is invalid.")
# Out:
# Enter your email address: ajstyles@gmail.com
# The email address is valid.

# %% [markdown]
# **5. Create a program that asks the user for the number of days they
# have delayed returning a library book. If the delay is less than or
# equal to 7 days, there is no fine. If the delay is between 8 and 30
# days, apply a fine of 2 rupees per day. If the delay is more than
# 30 days, apply a fine of 5 rupees per day. Print the total fine
# amount.**

# %%
days_delayed = int(input("Enter the number of days you have delayed returning the library book: "))

if days_delayed <= 7:
    fine = 0
elif 8 <= days_delayed <= 30:
    fine = 2 * days_delayed
else:
    fine = 5 * days_delayed

print(f"The total fine amount is {fine} rupees.")
# Out:
# Enter the number of days you have delayed returning the library book: 10
# The total fine amount is 20 rupees.

# %% [markdown]
# **6. Write a program that checks if a given character is a vowel. Use
# the in operator to check if the character is present in a string of
# vowels ("aeiou").**

# %%
char = input("Enter a character: ").lower()

if char in "aeiou":
    print(f"{char} is a vowel.")
else:
    print(f"{char} is not a vowel.")
# Out:
# Enter a character: a
# a is a vowel.

# %% [markdown]
# **7. Implement a program that calculates the factorial of a number
# using a loop.**

# %%
number = int(input("Enter a number: "))

factorial = 1
for i in range(1, number + 1):
    factorial *= i

print(f"The factorial of {number} is {factorial}.")
# Out:
# Enter a number: 5
# The factorial of 5 is 120.

# %% [markdown]
# **8. Generate the Fibonacci sequence (0, 1, 1, 2, 3, ...) up to a certain
# limit using a loop.**

# %%
limit = int(input("Enter the limit for the Fibonacci sequence: "))

a, b = 0, 1
print("Fibonacci sequence up to the limit:")

while a <= limit:
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter the limit for the Fibonacci sequence: 10
# Fibonacci sequence up to the limit:
# 0 1 1 2 3 5 8

# %% [markdown]
# **9. Create a number guessing game where the computer generates a
# random number and the user has to guess it within a certain
# number of attempts using a loop.**

# %%
import random

# Generate a random number between 1 and 100
random_number = random.randint(1, 100)
attempts = 10

print("Guess the number between 1 and 100. You have 10 attempts.")

for attempt in range(1, attempts + 1):
    guess = int(input(f"Attempt {attempt}: Enter your guess: "))

    if guess < random_number:
        print("Too low!")
    elif guess > random_number:
        print("Too high!")
    else:
        print(f"Congratulations! You guessed the number {random_number} correctly in {attempt} attempts.")
        break
else:
    print(f"Sorry, you've used all {attempts} attempts. The number was {random_number}.")
# Out:
# Guess the number between 1 and 100. You have 10 attempts.
# Attempt 1: Enter your guess: 30
# Too low!
# Attempt 2: Enter your guess: 60
# Too high!
# Attempt 3: Enter your guess: 45
# Too high!
# Attempt 4: Enter your guess: 50
# Too high!
# Attempt 5: Enter your guess: 40
# Too high!
# Attempt 6: Enter your guess: 36
# Too low!
# Attempt 7: Enter your guess: 38
# Too low!
# Attempt 8: Enter your guess: 39
# Congratulations! You guessed the number 39 correctly in 8 attempts.

# %% [markdown]
# **10. Write a menu driven calculator with following menu:**

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y != 0:
        return x / y
    else:
        return "Error! Division by zero."

while True:
    print("\nMenu:")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Exit")

    choice = input("Enter your choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator. Goodbye!")
        break

    if choice in ['1', '2', '3', '4']:
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
        except ValueError:
            print("Invalid input! Please enter numeric values.")
            continue

        if choice == '1':
            print(f"Result: {add(num1, num2)}")
        elif choice == '2':
            print(f"Result: {subtract(num1, num2)}")
        elif choice == '3':
            print(f"Result: {multiply(num1, num2)}")
        elif choice == '4':
            print(f"Result: {divide(num1, num2)}")
    else:
        print("Invalid choice! Please enter a number between 1 and 5.")
# Out:
# Menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1/2/3/4/5): 4
# Enter the first number: 3
# Enter the second number: 6
# Result: 0.5
#
# Menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1/2/3/4/5): 3
# Enter the first number: 1
# Enter the second number: 5
# Result: 5.0
#
# Menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1/2/3/4/5): 5
# Exiting the calculator. Goodbye!
